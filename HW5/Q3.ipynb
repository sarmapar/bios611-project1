# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from sklearn.manifold import TSNE

# %%
data = pd.read_csv(r'char_stats.csv')
data_numeric = data[["Intelligence","Strength","Speed","Durability","Power","Combat","Total"]]

# %%
tsne = TSNE(n_components=2)

# %%
tsne_results = tsne.fit_transform(data_numeric)
data['tsne1'] = tsne_results[:,0]
data['tsne2'] = tsne_results[:,1]
data_tsne = data[["Alignment","tsne1","tsne2"]]
data_tsne
# Out:
#     Alignment      tsne1      tsne2
# 0        good  11.093201   3.618740
# 1        good  -1.805313   9.448281
# 2        good   3.063468   4.451305
# 3        good -12.770295  18.212711
# 4         bad -14.797436  17.931196
# ..        ...        ...        ...
# 606      good  17.584452  -2.720033
# 607      good  15.305321  -1.451825
# 608      good -10.151369  16.522264
# 609      good   5.799506  12.382703
# 610       bad   2.483787  16.324585
#
# [611 rows x 3 columns]

# %%
data_tsne.to_csv(r'tsne.csv')

# %%
cols=[]
for i in data_tsne[["Alignment"]].to_numpy().tolist():
    if i==['bad']:
        cols.append('red')
    elif i==['good']:
        cols.append('green')
    elif i==["neutral"]:
        cols.append('blue')
    else:
        cols.append('gray')

plt.scatter(data_tsne[["tsne1"]], data_tsne[["tsne2"]], c=cols)
plt.ylabel("V2")
plt.xlabel("V1")
plt.savefig('tsne_plot_python.png')
